# %% [markdown]
# <a href="https://colab.research.google.com/github/AleksanderDanilian/headDetector/blob/main/yolov3_Head_Detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/wnov/Keras_Head_Detection_YoloV3.git
# Out:
# Cloning into 'Keras_Head_Detection_YoloV3'...
# remote: Enumerating objects: 97, done.
# remote: Total 97 (delta 0), reused 0 (delta 0), pack-reused 97
# Unpacking objects: 100% (97/97), done.

# %%
cd /content/Keras_Head_Detection_YoloV3
# Out:
# /content/Keras_Head_Detection_YoloV3

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 312 kB 8.7 MB/s
# ...
#      |████████████████████████████████| 92.6 MB 68 kB/s
# ...
#      |████████████████████████████████| 30.6 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 14.2 MB 17.3 MB/s
# ...
#      |████████████████████████████████| 13.8 MB 29.3 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 50.5 MB/s
# ...
#      |████████████████████████████████| 367 kB 47.2 MB/s
# ...
#   Created wheel for Pillow: filename=Pillow-5.0.0-cp37-cp37m-linux_x86_64.whl size=1067057 sha256=133969bff3d353b287682c0d5c3584487e9c5464884d6db02e44c7b83342f205
#   Stored in directory: /root/.cache/pip/wheels/0c/e9/3f/e1cf5b199032b95130c1e68222992ce83a78a51bdba0577a3b
# Successfully built Pillow
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: tensorflow-estimator
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wg6u0NIzDLA83n4AdKoF")
project = rf.workspace().project("head-detector")
dataset = project.version(1).download("yolokeras")
# Out:
# ...
#      |████████████████████████████████| 145 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 178 kB 36.4 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 44.3 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 50.9 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 14.5 MB/s
# ...
#      |████████████████████████████████| 67 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 138 kB 44.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 36.7 MB/s
# ...
#      |████████████████████████████████| 62 kB 632 kB/s
# ...
#   Created wheel for roboflow: filename=roboflow-0.2.1-py3-none-any.whl size=20914 sha256=947be6da2b3822432af5543960fbffa9c94d75d225aa3de3d5ea6d3e7661c8c8
#   Stored in directory: /root/.cache/pip/wheels/57/00/03/2d83f3e90ff41c36eef9c3747c328290c01b06e2619f9ed7b6
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=dba1f60a2cd71e79ac8b8165dbbbc0fb89862e192d4ddc7c2f667bf561f224d7
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# !python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5
# Out:
# --2021-12-17 10:25:53--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  79.0MB/s    in 3.0s
#
# 2021-12-17 10:25:56 (79.0 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %%
import os
folder = os.listdir('/content/Keras_Head_Detection_YoloV3/Head-Detector-1/train')

import shutil

shutil.move('/content/Keras_Head_Detection_YoloV3/Head-Detector-1/train/_annotations.txt', '/content/Keras_Head_Detection_YoloV3/Head-Detector-1')

# %%
# !pip install 'h5py==2.10.0' --force-reinstall
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 7.4 MB/s
# ...
#   Using cached numpy-1.21.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.4
#     Uninstalling numpy-1.21.4:
#       Successfully uninstalled numpy-1.21.4
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.4 which is incompatible.
# kapre 0.3.6 requires tensorflow>=2.0.0, but you have tensorflow 1.13.1 which is incompatible.
# ...

# %%
import shutil

shutil.copy('/content/Keras_Head_Detection_YoloV3/model_data/yolo.h5', '/content/Keras_Head_Detection_YoloV3/logs/001/trained_weights_final.h5', follow_symlinks=True)
# Out:
# '/content/Keras_Head_Detection_YoloV3/logs/001/trained_weights_final.h5'

# %%
# !python train.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
'trained_weights_stage_1.h5'
